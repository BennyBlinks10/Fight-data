# %%
import pandas as pd

# %%
passanger_df = pd.read_csv('AirlineScrappedReview.csv')

# %%
passanger_df
# Out:
#          Passanger_Name          Flying_month                  Route  Rating  \
# 0            Paige Boet             June 2023  New Orleans to London     1.0
# 1               S Layne            March 2023        London to Amman     1.0
# 2           E Lanewoski    Heathrow to Bodrum         Business Class     2.0
# 3           Joel Burman             June 2023        Amman to London     4.0
# 4               R Vines  London City to Ibiza         Business Class     7.0
# ...                 ...                   ...                    ...     ...
# 3575           W Benson                   NaN                    NaN     4.0
# 3576           S Luqman                   NaN                    NaN     4.0
# 3577            D Smith                   NaN                    NaN     4.0
# 3578           W Benson                   NaN                    NaN     6.0
# 3579  Michael Dielissen                   NaN                    NaN     8.0
#
# ...

# %%
passanger_df.describe()
# Out:
#             Rating
# count  3575.000000
# mean      4.790490
# std       3.170323
# min       1.000000
# 25%       2.000000
# 50%       4.000000
# 75%       8.000000
# max      10.000000

# %%
passanger_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3580 entries, 0 to 3579
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Passanger_Name  3580 non-null   object
#  1   Flying_month    2815 non-null   object
#  2   Route           2816 non-null   object
#  3   Rating          3575 non-null   float64
#  4   Verified        1270 non-null   object
#  5   Review_title    3580 non-null   object
#  6   Review_content  3580 non-null   object
#  7   Traveller_type  3580 non-null   object
#  8   Class           3579 non-null   object
# dtypes: float64(1), object(8)
# memory usage: 251.8+ KB

# %%
passanger_df.columns
# Out:
# Index(['Passanger_Name', 'Flying_month', 'Route', 'Rating', 'Verified',
#        'Review_title', 'Review_content', 'Traveller_type', 'Class'],
#       dtype='object')

# %%
passanger_df['Flying_month'] = pd.to_datetime(passanger_df['Flying_month'], errors='coerce')
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_8164\761250350.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   passanger_df['Flying_month'] = pd.to_datetime(passanger_df['Flying_month'], errors='coerce')

# %%
passanger_df
# Out:
#          Passanger_Name Flying_month                  Route  Rating  \
# 0            Paige Boet   2023-06-01  New Orleans to London     1.0
# 1               S Layne   2023-03-01        London to Amman     1.0
# 2           E Lanewoski          NaT         Business Class     2.0
# 3           Joel Burman   2023-06-01        Amman to London     4.0
# 4               R Vines          NaT         Business Class     7.0
# ...                 ...          ...                    ...     ...
# 3575           W Benson          NaT                    NaN     4.0
# 3576           S Luqman          NaT                    NaN     4.0
# 3577            D Smith          NaT                    NaN     4.0
# 3578           W Benson          NaT                    NaN     6.0
# 3579  Michael Dielissen          NaT                    NaN     8.0
#
#            Verified                            Review_title  \
# 0     Trip Verified             The airline lost my luggage
# ...

# %%
passanger_df.dropna(subset=['Flying_month'], inplace=True)

# %%
passanger_df
# Out:
#          Passanger_Name Flying_month                  Route  Rating  \
# 0            Paige Boet   2023-06-01  New Orleans to London     1.0
# 1               S Layne   2023-03-01        London to Amman     1.0
# 3           Joel Burman   2023-06-01        Amman to London     4.0
# 5                M King   2023-06-01   London to Washington     1.0
# 8        Carol Willmore   2023-06-01     London to Funchal      1.0
# ...                 ...          ...                    ...     ...
# 2779    Thomas Kingston   2014-11-01       London to Vienna     4.0
# 2788           C Barkei   2015-06-01             LHR to LUX     8.0
# 2795    Michael Stanley   2015-06-01             LHR to BKK     6.0
# 2798      Nazira Khatun   2015-06-01       London to Turkey    10.0
# 2799  Nur Afiqah Rahmat   2015-06-01    Abu Dhabi to Muscat     9.0
#
#            Verified                            Review_title  \
# 0     Trip Verified             The airline lost my luggage
# ...

# %%
passanger_df.reset_index(inplace=True,drop=True)

# %%
passanger_df.columns
# Out:
# Index(['Passanger_Name', 'Flying_month', 'Route', 'Rating', 'Verified',
#        'Review_title', 'Review_content', 'Traveller_type', 'Class'],
#       dtype='object')

# %%
words = ['to', 'via']

# %%
passanger_df = passanger_df[passanger_df['Route'].str.contains('|'.join(words),case=False, na=False)]

# %%
    passanger_df.head(20)
# Out:
#           Passanger_Name Flying_month  \
# 0             Paige Boet   2023-06-01
# 1                S Layne   2023-03-01
# 2            Joel Burman   2023-06-01
# 3                 M King   2023-06-01
# 4         Carol Willmore   2023-06-01
# 5          Nadine Kohler   2023-06-01
# 6                A. Adel   2023-06-01
# 7      Cosmin Stefanescu   2023-06-01
# 8      Emmeline Reichert   2023-06-01
# 9          Jamie Gooding   2023-06-01
# 10       Michael Hayward   2023-06-01
# 11      George W Edmonds   2023-06-01
# 12           K Pickering   2023-06-01
# 13             M Johnson   2023-03-01
# 14             V Samaras   2023-04-01
# 15           Ali Balandy   2023-05-01
# 16            A Robinson   2023-06-01
# 17              K Parker   2023-05-01
# 18           Tanya Tracy   2023-02-01
# 19  Christos Hadjipanayi   2023-03-01
#
#                                        Route  Rating       Verified  \
# 0                      New Orleans to London     1.0  Trip Verified
# ...

# %%
passanger_df = passanger_df[passanger_df['Class'].str.contains('Class',case=False, na=False)]

# %%
passanger_df=passanger_df[passanger_df['Traveller_type'].str.contains('Leisure',case=False, na=False)]

# %%
passanger_df.dropna(inplace=True)

# %%
passanger_df.reset_index(drop=True, inplace=True)

# %%
passanger_df
# Out:
#       Passanger_Name Flying_month  \
# 0         Paige Boet   2023-06-01
# 1            S Layne   2023-03-01
# 2        Joel Burman   2023-06-01
# 3             M King   2023-06-01
# 4     Carol Willmore   2023-06-01
# ..               ...          ...
# 382  Victor Mendonca   2017-11-01
# 383  Raymond Grayson   2017-08-01
# 384          A Lewis   2017-10-01
# 385    Ian Henderson   2017-10-01
# 386    Courtney Ross   2017-11-01
#
#                                               Route  Rating       Verified  \
# 0                             New Orleans to London     1.0  Trip Verified
# 1                                   London to Amman     1.0  Trip Verified
# 2                                   Amman to London     4.0   Not Verified
# 3                              London to Washington     1.0  Trip Verified
# 4                                London to Funchal      1.0   Not Verified
# ..                                              ...     ...            ...
# ...

# %%
passanger_df.to_csv('PassangerEdit.csv')
